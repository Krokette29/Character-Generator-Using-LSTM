# %%
"""
Minimal character-level LSTM model. Written by Ngoc Quan Pham
Code structure borrowed from the Vanilla RNN model from Andreij Karparthy @karparthy.
BSD License
"""
import numpy as np
from random import uniform
import sys

# %%
# Since numpy doesn't have a function for sigmoid
# We implement it manually here
def sigmoid(x):
    return 1 / (1 + np.exp(-x))


# The derivative of the sigmoid function
def dsigmoid(y):
    return y * (1 - y)


# The derivative of the tanh function
def dtanh(x):
    return 1 - x*x


# The numerically stable softmax implementation
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# %%
# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1115394 characters, 65 unique.

# %% [markdown]
# **此处有疑问，sys.argv怎么用？？（sys.argv[1]是我们run: "python lstm_py train"，其中的train,用于设置输入参数，选择不同的模式，比如train or gradientcheck）**

# %%
option = sys.argv[1]

# %%
# hyperparameters
emb_size = 4
hidden_size = 512  # size of hidden layer of neurons
seq_length = 64  # number of steps to unroll the RNN for
learning_rate = 5e-2
max_updates = 500000
std = 0.1

concat_size = emb_size + hidden_size

# %%
# model parameters
# char embedding parameters
Wex = np.random.randn(emb_size, vocab_size)*std # embedding layer

# LSTM parameters
Wf = np.random.randn(hidden_size, concat_size) * std # forget gate
Wi = np.random.randn(hidden_size, concat_size) * std # input gate
Wo = np.random.randn(hidden_size, concat_size) * std # output gate
Wc = np.random.randn(hidden_size, concat_size) * std # c term

bf = np.zeros((hidden_size, 1)) # forget bias
bi = np.zeros((hidden_size, 1)) # input bias
bo = np.zeros((hidden_size, 1)) # output bias
bc = np.zeros((hidden_size, 1)) # memory bias

# Output layer parameters
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
by = np.zeros((vocab_size, 1)) # output bias

# %% [markdown]
# ## 需要我们补充的部分1：向前传播

# %%
def forward(inputs, targets, memory):
    """
    inputs,targets are both list of integers.
    hprev is Hx1 array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """

    # The LSTM is different than the simple RNN that it has two memory cells
    # so here you need two different hidden layers
    hprev, cprev = memory

    # Here you should allocate some variables to store the activations during forward
    # One of them here is to store the hiddens and the cells
    xs, cs, hs, os, ps, ys, wes, zs, fgate, igate, chat, ogate = {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}

    hs[-1] = np.copy(hprev)
    cs[-1] = np.copy(cprev)

    loss = 0
    # forward pass
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        xs[t][inputs[t]] = 1

        # convert word indices to word embeddings
        wes[t] = np.dot(Wex, xs[t])

        # LSTM cell operation
        # first concatenate the input and h
        # This step is irregular (to save the amount of matrix multiplication we have to do)
        # I will refer to this vector as [h X]
        zs[t] = np.row_stack((hs[t-1], wes[t]))

        # YOUR IMPLEMENTATION should begin from here

        # compute the forget gate
        fgate[t] = sigmoid(np.dot(Wf, zs[t]) + bf)

        # compute the input gate
        igate[t] = sigmoid(np.dot(Wi, zs[t]) + bi)

        # compute the candidate memory
        chat[t] = np.tanh(np.dot(Wc, zs[t]) + bc)

        # new memory: applying forget gate on the previous memory
        # and then adding the input gate on the candidate memory
        cs[t] = fgate[t] * cs[t-1] + igate[t] * chat[t]

        # output gate
        ogate[t] = sigmoid(np.dot(Wo, zs[t]) + bo)

        # new hidden state for the LSTM
        hs[t] = ogate[t] * np.tanh(cs[t])

        # DONE LSTM
        # output layer - softmax and cross-entropy loss
        # unnormalized log probabilities for next chars

        os[t] = np.dot(Why, hs[t]) + by

        # softmax for probabilities for next chars
        ps[t] = softmax(os[t])

        # cross-entropy loss
        # cross entropy loss at time t:
        ys[t] = np.zeros((vocab_size, 1))
        
        # create an one hot vector for the label y
        ys[t][targets[t]] = 1

        # and then cross-entropy (see the elman-rnn file for the hint)
        loss_t = np.sum(-np.log(ps[t]) * ys[t])
        loss += loss_t

    # define your activations
    memory = (hs[len(inputs)-1], cs[len(inputs)-1])
    activations = (xs, cs, hs, os, ps, ys, wes, zs, fgate, igate, chat, ogate)

    return loss, activations, memory

# %% [markdown]
# ## 需要我们补充的部分2：向后传播

# %%
def backward(activations, clipping=True):

    # backward pass: compute gradients going backwards
    # Here we allocate memory for the gradients
    dWex, dWhy = np.zeros_like(Wex), np.zeros_like(Why)
    dby = np.zeros_like(by)
    dWf, dWi, dWc, dWo = np.zeros_like(Wf), np.zeros_like(Wi),np.zeros_like(Wc), np.zeros_like(Wo)
    dbf, dbi, dbc, dbo = np.zeros_like(bf), np.zeros_like(bi),np.zeros_like(bc), np.zeros_like(bo)

    xs, cs, hs, os, ps, ys, wes, zs, fgate, igate, chat, ogate = activations
    
    # similar to the hidden states in the vanilla RNN
    # We need to initialize the gradients for these variables
    dh = np.zeros_like(hs[0])
    dc = np.zeros_like(cs[0])
    dz = np.zeros_like(zs[0])
    
    # back propagation through time starts here
    for t in reversed(range(len(inputs))):

        # IMP2LEMENT YOUR BACKPROP HERE
        # refer to the file elman_rnn.py for more details
        
        # 1. equ.
        do = ps[t] - ys[t]
        # 2. equ.
        dWhy += np.dot(do, hs[t].T)
        dby += do
        dh += np.dot(Why.T, do)
        # 3. equ.
        dogate = dh * np.tanh(cs[t]) # false
        dc += dh * ogate[t] * dtanh(np.tanh(cs[t])) 
        # 4. equ.
        dWo += np.dot(dogate * dsigmoid(ogate[t]), zs[t].T) # false
        dbo += dogate * dsigmoid(ogate[t])
        dz += np.dot(Wo.T, dogate * dsigmoid(ogate[t]))
        # 5. equ.
        dfgate = dc * cs[t-1]
        digate = dc * chat[t]
        dchat = dc * igate[t]
        dc = dc * fgate[t]
        # 6. equ.
        dWc += np.dot(dchat * dtanh(chat[t]), zs[t].T)
        dz += np.dot(Wc.T, dchat * dtanh(chat[t]))
        dbc += dchat * dtanh(chat[t])
        # 7. equ.
        dWi += np.dot(digate * dsigmoid(igate[t]), zs[t].T)
        dz += np.dot(Wi.T, digate * dsigmoid(igate[t]))
        dbi += digate * dsigmoid(igate[t])
        # 8. equ.
        dWf += np.dot(dfgate * dsigmoid(fgate[t]), zs[t].T)
        dz += np.dot(Wf.T, dfgate * dsigmoid(fgate[t]))
        dbf += dfgate * dsigmoid(fgate[t])
        # 9. equ.
        dWex += np.dot(dz[len(hs[t-1]):], xs[t].T)
        dh = dz[:len(hs[t-1])]
        dz = 0
        
        if clipping:
            # clip to mitigate exploding gradients
            for dparam in [dWex, dWf, dWi, dWo, dWc, dbf, dbi, dbo, dbc, dWhy, dby]:
                np.clip(dparam, -5, 5, out=dparam)

    gradients = (dWex, dWf, dWi, dWo, dWc, dbf, dbi, dbo, dbc, dWhy, dby)
    
#     if test:
#         # Test of 2. equ.
#         print('Test of 2. equ.')
        

    return gradients

# %% [markdown]
# ## 需要我们补充的部分3：sample

# %%
def sample(memory, seed_ix, n):
    """
    sample a sequence of integers from the model
    h is memory state, seed_ix is seed letter for first time step
    """
    h, c = memory
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    
    generated_chars = []

    for t in range(n):
        # IMPLEMENT THE FORWARD FUNCTION ONE MORE TIME HERE
        # BUT YOU DON"T NEED TO STORE THE ACTIVATIONS
        wes = np.dot(Wex, x)
        zs = np.row_stack((h, wes))
        fgate = sigmoid(np.dot(Wf, zs) + bf)
        igate = sigmoid(np.dot(Wi, zs) + bi)
        chat = np.tanh(np.dot(Wc, zs) + bc)
        c = fgate * c + igate * chat
        ogate = sigmoid(np.dot(Wo, zs) + bo)
        h = ogate * np.tanh(c)
        
        o = np.dot(Why, h) + by
        p = softmax(o)

        # the the distribution, we randomly generate samples:
        ix = np.random.multinomial(1, p.ravel())
        x = np.zeros((vocab_size, 1))

        for j in range(len(ix)):
            if ix[j] == 1:
                index = j
        x[index] = 1
        generated_chars.append(index)

    return generated_chars

# %%
option = 'train'

if option == 'train':
    n, p = 0, 0
    n_updates = 0

    # momentum variables for Adagrad
    mWex, mWhy = np.zeros_like(Wex), np.zeros_like(Why)
    mby = np.zeros_like(by) 

    mWf, mWi, mWo, mWc = np.zeros_like(Wf), np.zeros_like(Wi), np.zeros_like(Wo), np.zeros_like(Wc)
    mbf, mbi, mbo, mbc = np.zeros_like(bf), np.zeros_like(bi), np.zeros_like(bo), np.zeros_like(bc)

    smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
    
    min_loss = 0

    while True:
        # prepare inputs (we're sweeping from left to right in steps seq_length long)
        if p+seq_length+1 >= len(data) or n == 0:
            hprev = np.zeros((hidden_size,1)) # reset RNN memory
            cprev = np.zeros((hidden_size,1))
            p = 0 # go from start of data
        inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
        targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

        # sample from the model now and then
        if n % 100 == 0:
            sample_ix = sample((hprev, cprev), inputs[0], 200)
            txt = ''.join(ix_to_char[ix] for ix in sample_ix)
            print ('----\n %s \n----' % (txt, ))

        # forward seq_length characters through the net and fetch gradient
        loss, activations, memory = forward(inputs, targets, (hprev, cprev))
        gradients = backward(activations, clipping=True)

        hprev, cprev = memory
        dWex, dWf, dWi, dWo, dWc, dbf, dbi, dbo, dbc, dWhy, dby = gradients
        smooth_loss = smooth_loss * 0.999 + loss * 0.001
        
        if smooth_loss < min_loss:
            min_loss = smooth_loss
            min_loss_iter = n
        if n % 100 == 0: 
            print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
            print('minimum loss: %f at iteration %i' %(min_loss, min_loss_iter))

        # perform parameter update with Adagrad
        for param, dparam, mem in zip([Wf, Wi, Wo, Wc, bf, bi, bo, bc, Wex, Why, by],
                                    [dWf, dWi, dWo, dWc, dbf, dbi, dbo, dbc, dWex, dWhy, dby],
                                    [mWf, mWi, mWo, mWc, mbf, mbi, mbo, mbc, mWex, mWhy, mby]):
            mem += dparam * dparam
            param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

        p += seq_length # move data pointer
        n += 1 # iteration counter
        n_updates += 1
        if n_updates >= max_updates:
            break

elif option == 'gradcheck':

    p = 0
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

    delta = 0.001

    hprev = np.zeros((hidden_size, 1))
    cprev = np.zeros((hidden_size, 1))

    memory = (hprev, cprev)

    loss, activations, _ = forward(inputs, targets, memory)
    gradients = backward(activations, clipping=False)
    dWex, dWf, dWi, dWo, dWc, dbf, dbi, dbo, dbc, dWhy, dby = gradients

    for weight, grad, name in zip([Wf, Wi, Wo, Wc, bf, bi, bo, bc, Wex, Why, by], 
                                   [dWf, dWi, dWo, dWc, dbf, dbi, dbo, dbc, dWex, dWhy, dby],
                                   ['Wf', 'Wi', 'Wo', 'Wc', 'bf', 'bi', 'bo', 'bc', 'Wex', 'Why', 'by']):

        str_ = ("Dimensions dont match between weight and gradient %s and %s." % (weight.shape, grad.shape))
        assert(weight.shape == grad.shape), str_

        wrong_flag = False
        
        print(name)
        for i in range(weight.size):
            # evaluate cost at [x + delta] and [x - delta]
            w = weight.flat[i]
            weight.flat[i] = w + delta
            loss_positive, _, _ = forward(inputs, targets, memory)
            weight.flat[i] = w - delta
            loss_negative, _, _ = forward(inputs, targets, memory)
            weight.flat[i] = w  # reset old value for this parameter

            grad_analytic = grad.flat[i]
            grad_numerical = (loss_positive - loss_negative) / ( 2 * delta )

            # compare the relative error between analytical and numerical gradients
            rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)

            if rel_error > 0.01:
#                 if name == 'Wo' or name == 'bo':
                print ('WARNING %f, %f => %e ' % (grad_numerical, grad_analytic, rel_error))
#                     print('i=%i' %i)
#                     print('numerical: %f, analytic: %f' %(grad_numerical * 1000, grad_analytic * 1000))
                wrong_flag = True
    
        if wrong_flag:
            print('This gradient is not correct!')
        else:
            print('Test pass!')
            

#     weight, grad, name = Wo, dWo, 'Wo'
    
#     str_ = ("Dimensions dont match between weight and gradient %s and %s." % (weight.shape, grad.shape))
#     assert(weight.shape == grad.shape), str_

#     wrong_flag = False

#     print(name)
#     for i in range(weight.size):
#         # evaluate cost at [x + delta] and [x - delta]
#         w = weight.flat[i]
#         weight.flat[i] = w + delta
#         loss_positive, _, _ = forward(inputs, targets, memory)
#         weight.flat[i] = w - delta
#         loss_negative, _, _ = forward(inputs, targets, memory)
#         weight.flat[i] = w  # reset old value for this parameter

#         grad_analytic = grad.flat[i]
#         grad_numerical = (loss_positive - loss_negative) / ( 2 * delta )

#         # compare the relative error between analytical and numerical gradients
#         rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)

#         if rel_error > 0.01:
# #                     print ('WARNING %f, %f => %e ' % (grad_numerical, grad_analytic, rel_error))
#             print('i=%i' %i)
#             print('numerical: %f, analytic: %f, rel_error: %f' %(grad_numerical * 1000, grad_analytic * 1000, rel_error))
#             wrong_flag = True
            
#     if wrong_flag:
#         print("This gradient is not correct!")
#     else:
#         print("Test pass!")
# Out:
# ----
#  nfGdk:MB;BQ!Cb!cUevmI'DEoNB?vc
# !&Dhl;FcT?HK.!'KVT c JmDdy'?hPS-JnF?EDhw:Z hNyYdI3TLqYFRMSdljFR!AQoTmd:icW!S!LHl.dziYyHToXTQpXM'd-:k?SV'esjsbTVf':Sif'hwN$&BFIILMyXFaY!WrLOfyFWPoZcfr,MTawdic;UJZpSWQgHOg
# ----
# iter 0, loss: 267.160774
# ----
#  neal heN pl he s
# a  ud ld, ch dunyesrtrg tz IuiAph
# l
# aev cel to'eedtaliu
# h z ntde?  f
# setbu
# N
# bn ewtBtCuhen yel ne  aiale
# ueap-ft,rla
#  aucoi,el ,
#  ttl sona,  th t
# cr tBie :ygTt neohlktiC ld  mr
# ed
# ----
# iter 100, loss: 263.108793
# ----
#  eeluh wty a g Ins
# ihesladee feitkes h wyah,ysstm thl hotl wos ioh nond  oui
# HoaniS tonl:rn
# Bos
# Mhte.i sos nh soaharou-nrr hoCm toei nud
# hotls hipwhd rnam H d mlil nierhd thlmas sicd tao ne aiIoan ooh
# ----
# iter 200, loss: 255.872668
# ----
#  sw
# VhiRhe wwsscnd gnde feah tane binrl yer heib yu
# IAwis,ree heu oel  teutauhatat miw sou hor binit atatitt as toucglde  reld hot, hin Teveh y uhe wir hetaw sawls.sirote
# sev ghey hal iheraityirt bit
# ----
# iter 300, loss: 248.055949
# ----
#  t iw cougth mle gount.
# tolish fro fhan then  h ke
# Herle ta give Fpfol
# caw tounreurt ofdaib
# Tof towo foneo ghotes yooest tonton the rot caaw Iore.:
# Wu
# moth'is a foof otawe Whe no Mha thaug uorheve
# Thiu
# ----
# iter 400, loss: 239.865152
# ----
#  rf theve saswiveuth, Ir m, hads coode,
#
# COweNcon:,
# Wouvy sous loks,
# Brterln Houm vinrekatttb; thaige wole motannsao
# Het mrtanneo
# Mha' m chy hose, yones sin rnrc. ma'lr co thin ac !yd alittog netheugh
# ----
# iter 500, loss: 231.736300
# ----
#   you yiue etm?ren then tir. ffatgiretese; ie Ofdc afh onv
# MBr Itrl buare so sflut me be
# Mamof you wenend ane'r:au natgaut an ofyere you tonn :r a ltepwid che canclen.
# nim tyecifanfey rete ofy yyy the
# ----
# iter 600, loss: 224.463050
# ----
#  alsidscs hi'ml yyosg, ow roke
# us vangh ham
# CCRUS:
# Se ke jer on wortinf,rs tims bon,e, woc hom' raek
# zink ti sine krem Ion!
# ter shoup, Mher-phe nhinu
# likotglesssy enit! afe onk  remlven pileer-ot bebd
# ----
# iter 700, loss: 217.450408
# ----
#  ur she lal soind whe our, Oodion onw fy nomeond:
# Ther Coed ol weenleis a riwh sen haun the npoc eub:.
# I hannung an shen
# qhe bereas nhe po tomog dhey
# fole ta hop we
# i forall woven
# Leout it. as and the
# ----
# iter 800, loss: 210.449760
# ----
#  rs
# none iven, Ias mo''res bous ifar cemolte a mas.
#
# CIRIOAANAS:
# Hase milr the gagtes,
# Yiu
# Tyanpte yims tayeoe':
# bettire anf i
# shey berenrl asd yru, is thim wheiveud,
# Whiw paith, bovectm, your thee wur
# ----
# iter 900, loss: 204.203190
# ----
#   sit hites misn preog thil dive ol ind wesale you'',s got ry beim
# Then, houre Anethire har of she thod of our
# you have yow hid thas pmete'l o ham the
# CiRpiNAN:
# We cous
# As she missey fu hit have this
# ----
# iter 1000, loss: 197.464030
# ----
#  inginb', Inw that shin rorth rad mof fikl.
#
# BIMTNIUS:
# He navennf whe leoce,
# Ye Raronle,
# Whancun'rh moteo: an: an? Wi brousun soar:
# Ind ind fisgh.
# Bet retgiune hot Talteogh?
#
# CORIOLANUS:
# I waonur, Thut
# ----
# iter 1100, loss: 191.307719
# ----
#  southets.
#
# MONiNIUS:
# Whes Sot det whaol,, One ond'lis
# The pitenene ind thas de balu.
#
# CONINIUS:
# Drild tach nr.
#
# CiNINIUS:
# Yous; heir re mlats arvol'iunso
# The pai thiir atted,:
# And te the pracld ha.
# C
# ----
# iter 1200, loss: 186.022095
# ----
#  eslvad,
# Whe stokteiiltolg hy whall,stas.
#
# BRUnUIUS:
# The pmath!
#
# BIMINIUS:
# Iy ol Therl thot of,
# Beer nof leath as to lefr,
# Annl the withens porser, ofl the brenp thecm an the mobkus:
# Whives heold epont
# ----
# iter 1300, loss: 180.865510
# ----
#   rotde Ir an the muwcitbrcem,
# andn letorluier cosle so goortete Come
# In, morg naC to the mosede 'roule hot.
#
# VOLUMNIA:
# I ghe rash
# That at to thon de dathay.
#
# VORULNIUS:
# Ol shes!
# Ca thy desmetheres:
# Ir
# ----
# iter 1400, loss: 176.204943
# ----
#
# I as as ofhunatercrure youc igpire fos he sen; theser rtiy,
# I Croik thear winnsy ches houves a'd, a lonpsyius sale. Puw on knarcnf,
# Ind shill ind, at phesilal.
#
# MENENIUS:
# Itod met.
#
# SiCINIUS:
# Thill w
# ----
# iter 1500, loss: 171.677951
# ----
#  snn
# Toress's, you  apve timefiam, sif-s pibpe: yous heve.
# On icade. somladd hiasss, he ane
# Vy forn, heinesave gope, you iplidiots goove,--!
#
# MEMENIUS:
# Lokl le.n, theas: wilges he alet of pher darl.
# In
# ----
# iter 1600, loss: 167.774472
# ----
#  e oe hac, duktens sorlle be for waod
# Mninemee af, cett of vilk a't hee,
# Nues fenver mov no morm then, hery feod's a'gope
#
# TORIOMANUS:
# I haplaols ther, than?
#
# FitIcIS:
# Nores and as borme mresm, the pil
# ----
# iter 1700, loss: 163.818840
# ----
#  Ufozat:
# Fhanl he oxcens thy tarl if luls is,
#
# Fecond Servingman:
# Ruve when !ns bu tornin hase as home hinl math acr; core bo nreater dearlds
# Rurteares enlaoute, thasss rarUaghithard,
# Thyiwe and nrhais
# ----
# iter 1800, loss: 160.230761
# ----
#   sove mave fonthich
# Romare the dors's' sate of pend letinvet.
# You of nacre that shacy bat to shied
# sermios me yave woi
# Setal; we vas Taccepiud-terl
# Ase walungsh Inncoiss, whale ouf
# The buns
# of btiagte
# ----
# iter 1900, loss: 157.064365
# ----
#
# Carl', werl aw ils de wirl come
# Ta phas i stour.d
# Mithre ax wo tha d urdon.
#
# CENENIUS:
# Not edar the mrey at has ertard'-thatesat'tech
# as the wored' lit as is ro thay:
#
# BRUTUN:
# ABd,nes asghon to masl,
# ----
# iter 2000, loss: 154.337416
# ----
#
# Fectond: I rris as a mas brat, you asades of or thon?
#
# MENENIUS:
# Hy war Issor ale cyad here the funeriRe.
#
# MENENIUS:
# Vot shot,
# Whit wat cerile meald, Ho;, andnlteir jovel asoy worky pay to are con
# bo
# ----
# iter 2100, loss: 151.502998
# ----
#  senlfed srow tale bonland
# Your nicIsun our avart.
# You lepill, 'red thy masik', shey oar puolas the,
# A kor we fo hone rlapn, as he, wile.
#
# VOLUMUIA
# So ,e! ouk rwom's, you mydaricoun: chibt, Ale mete ti
# ----
# iter 2200, loss: 149.593473
# ----
#
# Lpadler'. srrauts retermud prey forse than
# An e haver, what as your gotsomeleole?
#
# MENENIUS:
# MAme'ciniters, and not gome.
# Ye! Eirizirm
# Criye as le; the dettsotecimin:
# Werauns will well mecoal, phuve
#
# ----
# iter 2300, loss: 147.529460
# ----
#  le.
#
# ARFIDIUS:
# Hall snomd'taol bbes
# To ukane,
# Martid mondts! ne hav in all mildor',
# on ie hout bloreps the Rar! whereeside to wy sel, and mroan,
# He woole pyoirt, these oucithed.
# MCall nood shoult.'
# Lp
# ----
# iter 2400, loss: 145.543196
# ----
#  pikenbcianventancem ynur enoode thas I welrly
# Hes blogme your fole youras? I a kgove
# Wis Ine the you ofsiet the limabnmee:
# I worl. You anm the seonge. Has these?
# Whol atee thy kency this wourd of it,
# ----
# iter 2500, loss: 144.799086
# ----
#  ,, why as muanole,
# On gheak thy thew
# Ly phoudd,
# G,ance, rrove, fiven sir he bunds a brave:
# Ird In iaret aThoud danlt whach dound thus madst llenad
# To entt of I wom uledsanss dued
# Avol I vatt, Ind of t
# ----
# iter 2600, loss: 143.308571
# ----
#  nd dest, I blow!
# I lof.
# Iu the agtide torp, boc you ther horom.
#
# BdOUCESTER:
# Hour adeng, that cooith, his I our as meor me.
#
# GLOUCTTE:
# To berth mare.
# GADTICAEEERRs Barile ip nor ex
# Hid tonries thoug
# ----
# iter 2700, loss: 140.688351
# ----
#  ng this soed
# Enssaking, wath to you non'wor'r to ded inotud.
# Trepe noe, hers twankt in dess'n le to hel and,
# And seenlling hang your luge bote her,
# Anfn me spovh beet, fernert, forexw'r, Prato his pea
# ----
# iter 2800, loss: 139.875729
# ----
#  norre nour'nerstl.
#
# QUEEN SARGARET:
# Intsily you?
#
# HiSTRNS:
# Rush maven.
#
# QUEEN MARGARET:
# Shished, have, ladles toy himl thou sroald?
#
# QUEEN MHl:
# Nakled norl keare, you wall shoug! me bor'?
#
# GUEEN MARGA
# ----
# iter 2900, loss: 138.230416
# ----
#  her, y tell e the keds.
# When It it of is bapch wir masce heaw targir,
# Thound to wull peops crwilve
# mons pigselt wath fit to oer-ture tomups me inpidtry mid;
# Sith dangtited to of wenalk of Igheetrs,
# B
# ----
# iter 3000, loss: 136.919240
# ----
#  CLARENCE::
# But of thy luy in none; bee, glry you!s:
# Whe co, of ascoend thes uxand tre thr miinss i am.
#
# CARENCE:
# O? keen the donod thyereat, com a kams to le to kily
# At your dond, where beethan I smuo
# ----
# iter 3100, loss: 134.901818
# ----
#  RY
# How sor thit coundt owe foilnes,.-
# If; sonde I heall-noun will fove:
# Ind Ruared?
#
# CIREVDAr:
# OW, the stave us you move
# Hiw pynat in makeressaver that wonl galmapd dive is moup
# Tase eocmon and undere
# ----
# iter 3200, loss: 133.131605
# ----
#  s Is bu mich be.
#
# GUCHESS MF MOS:
# We woud you chapgel' standlmumas torctomeot hady
# Your and prevose mish my crewiow.
# Or vattand, of you,
# I crimeecke no rrooss my done
# I whit of you divh bide to make g
# ----
# iter 3300, loss: 132.342352
# ----
#   sigh of him gom and,
# Fail will bofe to bihend his no; setrreese af,
# Wee sith have sloend a baghon; whan cearcu,,
# That the noul id it fyow a kood Ine your en;
# And fit a prigch comatrlode cemm our
# The
# ----
# iter 3400, loss: 131.306234
# ----
#  Y IF Leod wath ur
# Your lragcle you:
#
# SRsHerd:
# Wath ald of Hisat on uswaithid norouvar',
# Seld selloust to dinch nabl o thithcess
# If seet theces of she crinuce pearouther sorath
# Het have you wold taliur
# ----
# iter 3500, loss: 129.948173
# ----
#  ate
#
# Yowh: I hispurt gomks patin as us thy Yorgs.
# Mowily and. Po bocht slipk, frallel'nd,
# Is aoll dis,
# Of than the coulie to all the wast;
# Thos fo lot his to you brongce to uwaf, as seed sire what
# The
# ----
# iter 3600, loss: 128.102740
# ----
#  rs.
#
# HASTINGS:
# I'll stand lord, 'narate.
#
# PACSESS Gp tit: OFwerd'!
# Musent to to their Qttare ot atpees;
# Bot that Cades your has you madt a bpeater,
# I han nob on the agp to dear noth?
# Fhome you, Mowerw
# ----
# iter 3700, loss: 126.839413
# ----
#  , and
# And the frome rillt lenate, you Heve you say;
# Fearer, mlow mi? for coras arliinch.
#
# TAREUFAEFY:
# I dan, plowset it and urpoaks puitpy
# And whe brod then, leot to croveroush.
#
# BOCGH:
# How I keat whe
# ----
# iter 3800, loss: 125.898437
# ----
#  Mordidiu, the well: nres both,
# Woold brok hes youk weaqd'r imett, shis, buth, which the gey
# le hours
# At luy, Gor, -toudliud well yoar,
# And timn yak, Anw your prate rosh moss-shan ate ithald wheik.
#
# BU
# ----
# iter 3900, loss: 125.084548
# ----
#  ve selpist
# notherse of hig woit renvood chomnry
# Heselle in pu.
#
# GLOUCESTER:
# He qosxs, of to beweratinge your keal.
# Chey wors their to, a withurf, pagiterny
# God diy with: bivennas on your groort-pull!
#
# ----
# iter 4000, loss: 124.443252
# ----
#  d voot hiug. ly sreet,
# And letaltt!y sitoes in qeos in the mond.
#
# DLAUCES:
# The nons and theokserf bet the tishers,
# O that ye catew will foecee as mo?
#
# BRADENEETEY:
# I e meveve,; I gpace,.
#
# QUEEN ELIZAH
# ----
# iter 4100, loss: 123.621515
# ----
#   snoun dis,
# I mad sreel wen-rs.
#
# BUCKINLHAM:
# Sore, cory mike srokl sangere he thimer his eus iu me:
# Po the land of in my enat they?
#
# BIRK RICHARD MII:
# Than Grorp thou, aswald ene Hit a'll all most!
#
# C
# ----
# iter 4200, loss: 122.959856
# ----
#  UTHASS OF YORK:
# That glout; I Reess of gatecre, my br;
# Whith than hibl thou eneur the histulf: mr this.
# Bfor yet my not with ale infus alnother,
# Thal pruy your linrurl Here ther keie tirh'r Coraol'.
# I
# ----
# iter 4300, loss: 122.393079
# ----
#  nlarde,
# Theu wald pad Ctraxthand, my lyrole frepsme beed tooc;
# Boir, gome'th agre, baty ever heraln
# Thou ro midt to pive, werl, the herpsat thy vildy.
# Ditheed my ladtson theme if qurithoes than,
# Fo sc
# ----
# iter 4400, loss: 121.519988
# ----
#  e?
#
# KING RICHARD III:
# What douns swass.
# KIrd Cuverence sae Ind dear;
# Ane renod of her iarhter of gigeed Jenl if.
#
# QUEEN ELIZABETT:
# Abd by the cromemor do ovor infelor as e ivea;
# Afdees sid of Lleat t
# ----
# iter 4500, loss: 119.641662
# ----
#  at sime and drom than so imlele of will
# And tencly lostand, mevayded tiness;
# Youg unertyrd I wellet by lefes'd
# As me sel groverbe your graceour ghomour's.
# The velpmy me wrouther for as ghall so weis
# T
# ----
# iter 4600, loss: 118.250183
# ----
#   the pueghor?
#
# BUCKINGHAM:
# B, lan, aNd your reate: phlavimilog,'s alm good.
#
# KONB RBCHAMD EICHARD III:
# Selour, there-for now here soud syaml
# you hath the hishtreri's,
# Whatf'd of bitiscert you gandse o
# ----
# iter 4700, loss: 117.928120
# ----
#   eweet Ife that the, baed Muscund.
# Fesu'pcrer-thertert spear not, to mene ofher goor-Is
# To tanten, as bobd', he mord the mafit,
# Firh me both the douch, soul-to you po as,
# The Iujings; so-mones of the
# ----
# iter 4800, loss: 118.276522
# ----
#   mowht, with disher dod, fare te?
#
# RINCt:
# Ghall deptide the councew ofle hak of dig,'
# Thlee and food gakiin all him foy Ye hathed,
# Eron to-blecer melenl! Wastre! Dave? that beasn; bat ameose!
# Mode a'v
# ----
# iter 4900, loss: 118.472588
# ----
#  t it ut eastrrol'?
#
# RAELMAY AFECHARD LI:
# If in the lunt of Yate genencessiting fatte
# If srould freat desreasut, and Bathoorss ute.
# Of the riughtl's shopls in thy deew.
#
# ANENB MORGOREN:
# Aafo so your hi
# ----
# iter 5000, loss: 118.732200
# ----
#  t he sresser to the gatet alm asid.
#
# KIUG RICHARD II:
# Shase gorband not bafchiand cinnot dat MamEconk
# Sint us bn tuslie to my deaty
# Gare the puptain vibthuir doove.
#
# THOMBS OF OIGGGRK PI:
# Sher not chi
# ----
# iter 5100, loss: 118.747380
# ----
#  tremieg, ow thy chacine,
# Solbove of Hee coldy and me, avaanth
# Mrcains the haniour leave
# In 'lfoedelt apvise of the mrade,
# The fius wornt a klain his, motherls may apm?
#
# DUNH OL:
# Marsoy of ol horess de
# ----
# iter 5200, loss: 118.569142
# ----
#  apon again:
# Hish she frow. I mouks hyath ludtt of on grrecome-slues,
# Ours hir in mond fheive thou Cawiunt, Duen' blood:
# Save send'e truitor not the frumt the slean.
# That leneece e bisth bever's thoue
# ----
# iter 5300, loss: 118.253789
# ----
#  ceres bingy.
# Have craeter of for for whath yes raries
# Tinbs, Ind winl mumind their wens?
# Tall fiwe in havh de fount ap weart
# shan his bufieg wercher on nor's tlerare.
#
# AUEENEFARE:
# My gormer our duncre
# ----
# iter 5400, loss: 117.709946
# ----
#  th, whis byan?
# Had nowerect for as my leates throof tousn fare's.
# Thy thouds prors wird thy deaunre scongsing wes;
# And thou ar migt; Now, some ptress, that nat maath's,
# Whoce, of his farktent that may
# ----
# iter 5500, loss: 117.489160
# ----
#  th Apblenon,
# Duw is nuve
# To-lay the grave likite in hapry,
# Than thete unceed asseens coon, him whath,
# What Yore what batiNt qougs unor's choskily dan;
# Evaner on morland his glaysorion
# parse, which sl.
# ----
# iter 5600, loss: 117.090393
# ----
#  usbom's refre.
#
# BUKH MOy:
# In yourth in the Dome, gorn the hiad.
# Levink in hem serdly, he reany in have;
# Betius hath eod despighes yous oriunft?
# Weer both than egeinf hear so here
# For an keeer so callo
# ----
# iter 5700, loss: 117.079883
# ----
#  ,
# And Now what I an etice to dirln; ad.
#
# SING RF:
# No, me moun my sirc: Gangofe on your,
# To comelafs, and girsly warsly we uncle,
# At, munt hats fare to budt his ciulluus to zes,
# Herl infanv'd, titring
# ----
# iter 5800, loss: 116.444695
# ----
#  ow,;
# Fo, dell you for were.
# Kgynince you, and miy llooke my horse.
#
# HENRY BOLINGBROKESEY:
# The king, to oot hir aud dipht exar 'nor to To-ages
# And all hen you arave as informingssrraches
# Woy und ofe,
# ----
# iter 5900, loss: 116.083307
# ----
#  gares 'teartion and
# Sings book'd ofe gtand'd have fears'l my pare.
#
# HINR RICHARD II:
# Sele, a wale the Lores rearund,
# With boting to gert at lise aulte goob Towears
# The sabn they havy thy haar in baes
# ----
# iter 6000, loss: 116.014090
# ----
#  her me ment.
#
# HENRY PORLERL:
# Now, and shath lean of the path deithers
# Which'sfing whish our mistre waul and.
#
# HING RICCARDP:
# It thou hew the have ban thy breaOnd trrant sirs
# Eog Heach of shoe yot pnac
# ----
# iter 6100, loss: 115.477656
# ----
#  oult I have carmon le deadt oar deathe
# Myall you! from his vateance vast he lake:
# We nakme,, in the keeve He; we all-anmd.
#
# HTHas MtROLEN:
# Wo loug tither ur his wpante dight-and of our at gusel
# Despen
# ----
# iter 6200, loss: 114.913381
# ----
#  t, ornome eesinm troughssate op is him
# And eals mundnesst the dorg on muolp.
#
# NORTENESH
# Nthan Itet, I, that whyas I, The dead,
# Thith both thr afprow of coot best lent Bnouge-thee
# Iurl fure forr srige'
# ----
# iter 6300, loss: 114.806222
# ----
#  Lus him shall me the dies eard'l ferent.
#
# HENRY BOLINGBRGKE:
# Crilesher, pasfae:
# Thanle mew hit this your lupise
# The buesch by dither, you treasfe's bile.
# As, hall be you wiely a gripe,
# Ame itcy betime
# ----
# iter 6400, loss: 114.384688
# ----
#  t in this'diin, you jack
# Kay, thy fair a crasts my s gridnnrss;
# That yaty untinn of byaatht itherd to then,
# As nroks, mess, my for heaven shall is groud's
# The ding blood weol prece, whom reods lercous
# ----
# iter 6500, loss: 113.616865
# ----
#  HEHot:
# My tor ly owth acoig'd soen; fom cillonaly
# I kinb the ange'p sigrs-nour apm.
# The anco to lest with my bane yearch.
#
# HINd RICHARD II:
# Go, is the heact and heppine minane your hand,
# And to thy ex
# ----
# iter 6600, loss: 113.070058
# ----
#  itates stords comsusiess?
# Whone sent stef my houre are Comerlu,
# MHay to wile to nore my nomy Os news;
# There sreaktbs thou woullss the firerte frincs your gates,
# And asser tombert, so trorm thou farest
# ----
# iter 6700, loss: 112.154474
# ----
#   moar'r on ord?
#
# DUCHEMS OF YORK:
# As what is murtt and love and stand of heart
# At uthith.
#
# NUCHESS OF SORG:
# Nako come so hear son the iard atare
# That in thee, apon kest?
# S NHEr: whit the come and tol
# ----
# iter 6800, loss: 111.236600
# ----
#  Ot ofpe this pracked bary to nael
# Who laik my Lochort, ait yours vilouut?
# Andith'n firss my boet agpearly op Hands
# The stipn'd your wind grinfds prom'd lews so will;
# Well young, as hyarl the comtanen
# ----
# iter 6900, loss: 111.156920
# ----
#   me gyouguadone.
#
# FEDRY Mencor:
# Po breath pithiant is the me;
# And geimesins who headt. to lut, wistwer to krast,
# Tripason hy velainsw freater excarious tluts,
# As is were, wond-tower with subeccalle,
# F
# ----
# iter 7000, loss: 111.374044
# ----
#  y.
#
# POMMO:
# Why lives hald blomd and tive beboge,
# Bet more reter a puwient.
#
# MEPELOT:
# Luik e dedocd, and sided fore:
# O sweak phall's mrhawt a some curson deed?
#
# PAMPOLIO:
# I, what.'' plot, but lise ent
# ----
# iter 7100, loss: 111.651021
# ----
#  ear: Trreathey,
# Normerleble.
#
# DAPY CAPULET:
# For ny, ,et-strong: say theid maigen.'-whithal pall's trous,
# Taln the futeente tulks then, some, ay gare oithatie,
# But they ne aart; as alone's,'
#
# GELIL:
# Sh
# ----
# iter 7200, loss: 112.370950
# ----
#   him this yeaks gormon leas shall
# The lackencsfers ton theig treagers shances;
# Ceven faron thetengal's bis; ,ou fool;
# Mranple baerieg and barr, It I holl,
# A bive!
#
# TEMCUTIO:
# Thou shall print, and whes
# ----
# iter 7300, loss: 112.808751
# ----
#
#
# RImECET:
# Eod the monn that the len?
#
# RAEVO:
# Oarlay then lay my grair ape, Pay the wale
# Twackide sit chares of you, do le; criet is she.
#
# JULIET:
# Asterd me shale having;
# Wer so many not a midily lipe
# ----
# iter 7400, loss: 113.074172
# ----
#  oiven.
#
# ROMEO:
# Had tnrsue afteect tongunt Pither lesile?
#
# ROMEO:
# 'ither thou ar asunt, amesy herefay,
# And be heavence woild the feitue with Bover.
# Os storeow of I me fought thark telmen:
# Shines thee t
# ----
# iter 7500, loss: 112.781675
# ----
#  e kands from to bay by weull?
# A collow Monre to mecertlave not gole,
# Surmined mine: my thou will'sed Confiny,
# I's stufe the coursiin light thee thith neviod wathy!
# Rincerer uny ly deane, I would chose
# ----
# iter 7600, loss: 112.536566
# ----
#   more,
# not part on me they fovery dowe thy hoiss is I mest
# Food. I lith no' too bon. Gwand't he tent, not spook
# For
# I kyishos, there, whoosess ofn food hol
# Apceichs not on toncoe.
#
# ROREO:
# An thy reet
# ----
# iter 7700, loss: 112.716263
# ----
#  on to this hast
# ledt: for shikl she sen enrie sis this amy
# Rtisby, welps if dand for this shillsthan!
#
# LOLst Resule:
# And show you
# nath mucrst dones, in her good dour poor;
# Non herd? 'tir dews?
#
# MERCUT
# ----
# iter 7800, loss: 112.497553
# ----
#  valiUnant cime,
# Tluipht be thoe intescamed wander is the with, when uNo thoubs sway
# and we menrer ly, frith hand,, thy cousin antel a
# That e frafges kIes twomed you, banded's deak,
# And yages cas woend
# ----
# iter 7900, loss: 112.329418
# ----
#  o ly gondent.
# With me deaves feritay, in then Sarking:
# Bug the did'le I am hus strilps?
#
# SRINE:
# O have as, Jean, whose mupt?
#
# BENVOLIO:
# Thosbenge, gale hos arayt,
# To his vile id his be melil,
# The what
# ----
# iter 8000, loss: 112.331526
# ----
#  nyed bleod lirereds.
# That fogging in nven! you'd?
# Mome-neall's snapk, coarisucal well there in heaven.
# In sne, had, but mase not'w Rosesring swane's in their thant!
# Tyookks but 'secy Rovarius comsored
# ----
# iter 8100, loss: 112.460299
# ----
#  blore,
# ADd reed on theo hatt to to amikip!
# That Rrmace your eweipe, mether to theo buoks;
# The own thy thisallrile: then? not bave and prunce's hooly
# They well holimh swore qeralt deaan?
# Butheron thee
# ----
# iter 8200, loss: 112.056798
# ----
#  ndolvangssorious lies,
# Woild lroke in the rover we, you,, as me consude:
# But our mare winr Dodro lance and lyqoke.
# Hisher day, aw is the ly care, at but to:
# If net you, strepk dear your bay hay.
# if th
# ----
# iter 8300, loss: 111.759174
# ----
#  call the ear with in.
# What, let, ther'fucer ip ruching'd mornee,
# So rakeven, profon thank?
#
# dONGt CAPUTAO:
# Srove,, sTukemen, asay.
#
# LADY CAPULET:
# Thing, new to it, tiles fare than: wIs theuvoor;
# That
# ----
# iter 8400, loss: 111.214737
# ----
#  y bus srowf,
# Brofw both no spcorth
# Pither day not faelle so love thas
# Cruny you, and us but lut me dear hence.
#
# JULIET:
# Soon nliut, thou art thee line coununt thy lad.
#
# FRIAR LAURENCE:
# Who chooss digc
# ----
# iter 8500, loss: 110.429017
# ----
#  shaed may bit ly foith have:
# Un stark a RucuSot mayce! the with we cucherfoud both!
# Mim, dee, mese with ane prey to-glect jid ont much for
# and you serf him.
# As thre, be mired; nuh I'll become i- hinde
# ----
# iter 8600, loss: 110.080621
# ----
#  ge.
#
# yUlAA:
# Have muth out by friend marrs to chats a this she.
#
# SRrsace:
# I with mut un exly'
#
# PETEO:
# No to it niere, way, -tay, coll you faith so none! having un my swaud enet,
# Oun dons. Gy a spiGt at
# ----
# iter 8700, loss: 110.155189
# ----
#  serf.
#
# CORERRI:
# I do nend treath.
# O marewed'd; a' well, nemmel bet:
# Hourt, marss watth hing eothy himdand to unout.
#
# NRRBES OORE:
# O, the fropor despetring bodt Ratchan: her;
# To me here our e mistor ch
# ----
# iter 8800, loss: 110.563310
# ----
#   agity with maserapt,
# For yot come me sight my loousy:
# And your bonort.
# Hars hasterEne go-bkamy Ir my?
# Lives there? Mupcatio, to done;
# Buvesy, star in ewpander wtiln wey tig:
# He more arole twouwe I w
# ----
# iter 8900, loss: 110.380935
# ----
#  miur shourd condrel Couply room kither gore;
# Onte! bongimet abd weard his lundang manr.
#
# PRMBELEE:
# Go should liinos makowed Tapsand.
#
# FurAO:
# Then yet a comedor, as mate; cousin ham?
# His then that is a
# ----
# iter 9000, loss: 109.694025
# ----
#  hall fellors of son jen-lateras,
# Youk dons
# Fut thy and that thice tall thy sools,
# Hear thear trees fre. Endint with me toou.
# Shall most me in the fatcet oit more
# Gove in hes ly tliuthilm.
#
# ALITC:
# You
# ----
# iter 9100, loss: 109.631760
# ----
#
# For thy tool: and I read fevens of a mannced neal is werr.
#
# KANGEG:
# He goman us mo! in the bahime, toll,
# Fever three menrspither holy as wene, dids.
#
# YORK:
# For this name of tikeing dead, and reings,
#
# ----
# iter 9200, loss: 108.661782
# ----
#  y.
# That it thee will we'll till my seakrs shall be kee
# Sondends and hear live upmord, and levily sey Clpeatt.
# Ye! hak I revisn Dlote so pnevening oret,
# That now the awe ols forthoud wifl op on hyard,
#
# ----
# iter 9300, loss: 108.518048
# ----
#  wull of and the furnres the crosn flom't maked,
# End yos both stord to ane as insess,
# Aven dake at your house; to their exet.
#
# SING HENRY VI:
# Buth the gaustay, Whele, Mawondt me Leant,
# Lenam! Head pave
# ----
# iter 9400, loss: 108.601889
# ----
#  indet me oncessay of York;
# 'ee qefory gores chance how'runot, sut, 'tis all,
# Ard next they sake is he beaenor scaud, wold
# Messin the sleet confond sourcounss and,
# That bust thy ferain this maniriod co
# ----
# iter 9500, loss: 108.610156
# ----
#   my frony, head:
# Therkefe us: -Tun batt, this sleig ipon my lifk
# songicain to bbyet thy night abd tearce,
# And in their dimior. I croars their beidqus preate:
# Is day me weetlies thou art thougkt we lea
# ----
# iter 9600, loss: 108.461894
# ----
#
# Mry made can King vathem'dsfolner with forth their badstare thee.
# But such his headt'd he gold you the nather;
# Whocowed this stretued day, and his like a will then these?
#
# MIsse MiLsaG ECY:
# 'tard gat
# ----
# iter 9700, loss: 107.742363
# ----
#  o the king,
# Ty elloricy riamner, Lroties caned,
# My froece shelond's to heavy oue domes fonther,
# A uuntomifudslie Intedfel tpeds; Slinfher bying Glajtors!
# Thyn'kers night the ridd I comen!
# Herave yourg
# ----
# iter 9800, loss: 107.545917
# ----
#   the wath the shall mas, kupd, I reach:
# My glief or kieg please of shound can
# Eptarlut by hele this lafy: for but with the noy.
#
# WARWICK:
# Aterle, should be to luke speaks,
# Bet the death paless same my
# ----
# iter 9900, loss: 107.250191
# ----
#  akunges-the monger wreth be cator man it;
# But sbeksting lingt, as awayed'd to tolp,
# And gurire of linamt is not Iness planchy;
# Llows now hil be a meapt to fathert,
# No wath a king as devent of 'naintt
# ----
# iter 10000, loss: 106.524140
# ----
#  gress merpeiray. she farewel of thy brood.
# Ay, my son qiterfelly veny, Ttorkitime eogh,
# And here word trise wisw a sobnon is ery.
#
# KING EDWARD IV:
# You hach min-tty dudsly balege him.
#
# GLOUCESTER:
# By g
# ----
# iter 10100, loss: 104.683684
# ----
#   and greit words, arl of a wood fream;
# So do breet in Rlitor, Jid secuars-to michth
# Where ar Geptat bight sors armine watw,
# Enderige the grads,
# Were sing o'r mest?
# Now, mewsings, and that thime cun in
# ----
# iter 10200, loss: 104.945764
# ----
#  t hin,
# You valwiins former tray loves her that rosh
# That dewer truat vistave for mister king.
#
# CLIRCERE:
# All thy 'monson s night,
# That sud forievatiok:
# At fin It decine gatwillfer hearth
# Lried his sit
# ----
# iter 10300, loss: 104.435300
# ----
#  bodterfunt.
#
# MLATEUGEF:
# How rasy, you rnowe 'twanks or watier?
#
# GOd Leeten:
# Had tomes a take you kively warthy headt.
#
# PLOUCESTER:
# And, but very with merserving let, and well as midawe.
# 3ut should des
# ----
# iter 10400, loss: 103.655628
# ----
#  wn contres,
# And the dorry, hole's linke of Lance.
# Mas all thrie takence to Montague.
#
# WARWICK:
# What have mence's and Ed, we do loth-of unsard,
# They herce mase his tornt nebks onstifed wey
# Whiss lefgin
# ----
# iter 10500, loss: 103.124381
# ----
#  ht.
#
# Thard Masqe:
# And menry't morair to shall by commiels,
# And heart now hath speath Walling gongows of Bovet;
# Bet thereseven the plan, may strengt to wish
# To that senturondej to refent;
# And I rrew is
# ----
# iter 10600, loss: 102.656660
# ----
#  ion, and wity to redings
# Spiends suid and I qundoksuon for moreruld.
#
# CLARENCE:
# Yet I
# That you fruw you till thy friverime,
# And wencest to vansanded and goldar ased.
#
# MLARONCE:
# Whosinge's ove merce in
# ----
# iter 10700, loss: 102.416515
# ----
#  t-none.
#
# ROMERSE:
# But a Furlave the mattar thy fach:
# Buramk and make forerth, and the shie hind!
# Ato the comes, and In the dest,
# And unlook foo to to the hipgne. His sraet:
# Bore Wacw us his nebssiaged
# ----
# iter 10800, loss: 101.783322
# ----
#  lt me hence ofw rlouk my baln.
# She hasth becose hakmly hands, I selatt and wise.
# Come, 'tis 'ing Kerjad'o she from the pig,
# Thou entel thought fould op bucking bod
# To our ares his le sat seik of so pe
# ----
# iter 10900, loss: 101.978670
# ----
#  oal fort?
#
# HASWICK:
# What's too his word him: Serjit thou folmual his lires.
#
# WARWICK:
# Nay you flow ham lut him;
# Wercetm up eush make the right my cavess hiusemf,
# And po ont, and my handhnre, luttsh of
# ----
# iter 11000, loss: 101.389646
# ----
#   news'd thou, Clarfncest in mire:
# Bmows KTippicuar the wasreculy that now thee says
# Sink Thisting with blood so lich of Ansarf;
# Ix watwer: so goar with in mint of lipe their obe.
#
# GLOUCESTER:
# Now, tha
# ----
# iter 11100, loss: 101.505669
# ----
#   so, melly, their fay, Erward! deseds to brave.
#
# MOMTOOTER:
# They speak, twis may here heave them you me.
#
# PELIXEN:
# What now cretard'd not a moyalle
# To I sespes thosed whet, our re'ns
# Nor having livent
# ----
# iter 11200, loss: 102.632056
# ----
#  ting; there there a eret one Fordsth,
# And flom I thound strakbest sirper hed'.
#
# LEONTES:
# My raugert: steak ray to-liy, your beans, givy dead;
# Thy gall'ds the survence boint; forlwt made.
# At I shupent
# ----
# iter 11300, loss: 103.628459
# ----
#   to his be kotes it the seuotence?
#
# CAMILLO:
# Worze my and dey qulen:
# Is rearnnings: she sagisw? is mine so spepuce.
# Now morty mocchnre! and munime
# Of so then, you inpe the gos-e you xespored.
#
# LOMGITH
# ----
# iter 11400, loss: 104.173321
# ----
#  enry freed there forts,
# And he childs stand's ere
# Of figed a gocfont? I mark she bon of's, I'll hil
# Is now rake pre-king kaming forgh:
# So wort artars, hear to be hilse made:
# What have his that otn mas
# ----
# iter 11500, loss: 104.396680
# ----
#  m plets the man swich thus; for beRlmes
# And Histold fool banisht that hif to boyal
# If you kefpecutter's seangs dours on told your Brtumen
# I hand thoe prome in pureteing.
#
# SEMISLOUS:
# Ovenner, I maral,
# ----
# iter 11600, loss: 104.689382
# ----
#  uch'd keee castles, and a crown you.
#
# ANTIVULEIN:
# Yoursech allow't mads, that shame bet,
# That partt of beal the doce cour'ar, bearour have to call;
# I comper the this, my lord.
#
# LEONTES:
# For qarse, my
# ----
# iter 11700, loss: 104.659646
# ----
#  I rest you his traitor
# Ensllat; to be, wwat orn meteluns Freslead toweo say.
#
# Fords ELiGCe:
# Good their Nontuge on parined pelaceo'
#
# LEONTES:
# Athore, fithty:
#
# BEONTES:
# I loss
# Tomgoem, that lost demendy
# ----
# iter 11800, loss: 104.744158
# ----
#  goces, friendd,
# On herrine when but then that he moy?
#
# PiULINA:
# A moth a to your -ppeaOris of my
# Cude and fierant hastross cleeds
# If so your prace: with acured,
# And the kivil, stconmibds.
#
# PEONTES:
# Th
# ----
# iter 11900, loss: 105.057490
# ----
#  ce
# Of seech youther
# Wercain'd her creat thus, araar: iW pill'd, and devennes
# I, for heaven, as honenes, whyn have propert,-noble you qutie
# To keing iuteryt toud thoo fare: iAreet!
# They ade agpoot that
# ----
# iter 12000, loss: 105.194846
# ----
#  ere eon grancer brotkee
# Undersal bean the qlocdecue; in thing: there.
#
# LErIsm:
# Werw be that have ars. Thanks see my page
# My
# Incried me to as in, and caynt fore
# mope come thouldss of it, when the Pewer
# ----
# iter 12100, loss: 106.168156
# ----
#  to peetre my
# Dless and me? and friev, meteemy yous execigen;
# The ifforsing as mack to kisrow and sif; I have shalt like
# Than's a
# ip pertory wuter
# Os nobely biarcul and minert
# I courd you say we pospen
# ----
# iter 12200, loss: 106.638377
# ----
#  aefed, and then like eart blush werl suut on his
# Doorest, detire and sweet
# rellow in thee,-sin's rauth not youl stice that herrlay
# And gare your mared.
#
# PERDITA:
# Sio, which is since of it she platious
# ----
# iter 12300, loss: 106.899623
# ----
#  s,
# Of thoughen. I line their trrasury say your daster besters
# Wakese fair-dossrawe; as I think wenter more come, and
# you crich to biirons to ghence: whal you are.
#
# SiRSAL:
# Had come; I am sitt etter of
# ----
# iter 12400, loss: 107.337701
# ----
#  uartlen, ses him saycald?
#
# FLORIZEL:
# Be hand! when till of
# thing. if this ese what? 'in foot fear havel
# Thay brother.
#
# yORI:
# Of it to this some glow.
#
# OUTOLYAUS:
# For for your capune Cawizes fealy were
# ----
# iter 12500, loss: 106.912670
# ----
#   speak for shall ut once
# Mafce you arecomery bealist; and, I is
# But in this minert, what seize my done.
#
# SpORIZEL:
# Dodting, ,in;
# There line hinour pas't thou my there is a grace
# Leing awain it bodes.
# ----
# iter 12600, loss: 106.397302
# ----
#  .
#
# AUTOLYCUS:
# Wive the king: the terphised himself you, to my,
# With hour thee cullf me, friends hand, no,
# I say servanty fumtery
# Tpresfge o twich to more beane instens the Gebteecous.
#
# AUTOLYCUS:
# But
# ----
# iter 12700, loss: 106.171763
# ----
#  rved, the vam your sinver be the miks-more hatchipy
# alout, therein, he shall dishomedt of the peacieg: and sey these.
#
# Clown:
# What be avin!s a truth zill, lick so tard, alank: sif.
#
# Clown:
# 'To cume is
# ----
# iter 12800, loss: 105.528474
# ----
#  he have hores
# And bront Momerate what you, goon: To memence,
# Yow, and seems wire full him.
#
# AUTOLYCUS:
# Pear mins, mowt'st, it,.
# And my king's looks, He hell'fes, nor
# think. 't dey that mareself to ben
# ----
# iter 12900, loss: 105.423534
# ----
#  e,
# but whose verteing is the did we dost wonth and Begessies
#
# Gorle?
# Comes a crowe, and daughter to the lyoss. O ssech; take us
# this yend to to them come, that she mort afdaeds,
# WAtree a shall preate
# ----
# iter 13000, loss: 105.098126
# ----
#  y but ray.
# ADUNASES:
# We so with you.
#
# AUTOLYCUS:
# Mught ip spann and fo, to be
# Ggoncised still siy. I will with the were so that eevence
# and batt: would food wand'd and the will promes.
#
# FlOsherd:
# Not
# ----
# iter 13100, loss: 104.553827
# ----
#  rs, good no sweet more; then yet you
# And challe at our state fither and that
# eeed. Afterfs, yamen,
# In very or, man, bo hich
# Indur as are so are to my depy of
# This bauth perporm for comfort dest yake,
# ----
# iter 13200, loss: 104.156014
# ----
#  xedition
# Dirmoce, who had I costier.
#
# HERMIOCE:
# I'll pristy your Pepols.
#
# LUCIO:
# Acos: not you have not and wwole your;
# Che wert the trear nobe with her of the olace with chence
# As all Eachers, tende:
# ----
# iter 13300, loss: 104.292265
# ----
#  iuld any
# for the good pord carrs of the cursters;
# strew ushalbous worss you, uppenithed,
# I am po be qufenut done your nrgeingous of hence,
# Dive, -uruther of hand me
# Wullpised till tale be:
# there by cu
# ----
# iter 13400, loss: 104.210811
# ----
#  o is ly yaille so.
#
# LUCIO:
# Ayd you senes
# Thou was to maje those grosns him sofryer
# Yather with sunpe: who I'll manSion all beignigly thou
# Angor that this fritht to my precexstres,
# Come utsagt ut hos o
# ----
# iter 13500, loss: 104.483988
# ----
#  ure was to uple purmost? I did it in: your born.
#
# ELBOW:
# Noy, stay, with with the onither kase for sin; those soy?
# For there'f longs more-six, indel that we food? Harl uuswer'd
# but no, an onemiths. O
# ----
# iter 13600, loss: 104.002739
# ----
#  vaptee a woran po thousand.
#
# ELHeng:
# Condtone sreed le?
#
# ELBOW:
# So nocfe, Of peace your comfacbe, 'tis it bedore some
# Andol he pee thou carins?
#
# PUMP YESS:
# Not you foe house, see: ly dae.
#
# ESCALUS:
# Pe
# ----
# iter 13700, loss: 103.219239
# ----
#  , lutt then' is the mard; mend rase
# Terlsirated a fe taker of me,-live,
# shore what thrsely sart thy outh me.
#
# PUGCLO:
# Block, the proth poor wele, norl that sir.
#
# ISABELLA:
# Dites a worsines.--hours my
# ----
# iter 13800, loss: 102.641265
# ----
#  is would be thy are in eyguest
# of ullide time stasgs to have onsites;
# When Is post for this nemeon sweet them, le bare,
# Mome, that sif the a kinge waslun on me:
# Allos hamk like shopitteirs mistrace,
# A
# ----
# iter 13900, loss: 102.324302
# ----
#   the sechs for nuce: and to us?
#
# ISABELLA:
# In proventt him that for nor, thou art
#
# ANGELO:
# Canness: it strange you holitare, let what ay life.
#
# ISABELLA:
# Lelevitame and shall never ag yot,
# I voal howk
# ----
# iter 14000, loss: 102.145856
# ----
#  ige: I was my pote.
#
# CLAUDIO:
# Bried shain best swoem-bat was my way ame a life.
#
# DUKE VINCENTIO:
# I! hath shall I was not it foruting he in the couldes.
#
# ISABELLA:
# O forn; I swear your cate, 'Iy and de
# ----
# iter 14100, loss: 101.830932
# ----
#  bkel whice see the ebbown hose.
# I woulud? no sither? that you but wath baigos
# and anroy a like he a preasume, should:
# I dibky got how inmeigatio still. Witherm!
#
# ISABELLA:
# The body wart, farele.
#
# DUKE
# ----
# iter 14200, loss: 101.752659
# ----
#  the meinnul,
# His'll? That that; we is a pebd of my agturply?
#
# DUKE VINCENTIO:
# Luke in evarullows. frimont knowledd, new, for thum.
#
# DUKE VINCENTIO:
# The muint whete he will tome none, yet jepttious gla
# ----
# iter 14300, loss: 101.548823
# ----
#   diel him: and vinting grocks:
# But if you have the comes mightress honest!
# Merting out good proclacien: ay iol hath sigt
# Ticely alqeas, kitter him, I grieve delieved
# it up all the his lipsted;
# Becans,
# ----
# iter 14400, loss: 101.336532
# ----
#  derfore is rewernseot!
# I pray to be truam, desirerts him, here have speak to-woran:
# I pray which srear!--luck be anvinon by sid, if in'.
#
# HERIO:
# To is with mead thimk evered it apvaner as meche with
# k
# ----
# iter 14500, loss: 101.072455
# ----
#  ss ore
# At were, if to my waxking of his poes
# not: -tear some swilld and how no son;
# to it tekm on? his pisen vangen to entre
# un intreicht little now, and in the duckied himbe
# To be rourninget, sir.
#
# P
# ----
# iter 14600, loss: 100.678245
# ----
#  ourlester by the buit, canter?
#
# DUKE VINCENTIO:
# The were touched is rinon', at my would; mastes
# and not to myas werp crocle shall aventey
# to steed be drat. But the worrd.
# That .tpear un'pisy to je him
# ----
# iter 14700, loss: 100.230137
# ----
#  sself uloners! Y roob and not oe mrinate!
# I gratted retired: if the proched anded-thange
# Wipting he whony bace spares wrence; no well.
#
# ANGELO:
# Most reing slees, this your either's?
#
# DUKE VINCENTIO:
# I
# ----
# iter 14800, loss: 99.884237
# ----
#  onventiness back fors
# This dynwmace
# To do moy thun me on Mouris on
# Andowty or
# To take reasonghiod sifot
# And the instrue with you some her renw retise.
# I am above. Gewed, I both repised him ene, thinks
# ----
# iter 14900, loss: 99.258170

# %%
# import os
# import pprint
# import tensorflow as tf

# if 'COLAB_TPU_ADDR' not in os.environ:
#   print('ERROR: Not connected to a TPU runtime')
# else:
#   tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
#   print ('TPU address is', tpu_address)

#   with tf.Session(tpu_address) as session:
#     devices = session.list_devices()

#   print('TPU devices:')
#   pprint.pprint(devices)
